# %%
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow
import keras
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
df = pd.read_pickle('./data/final_df')

# %%
X = df.drop(['Kp','ap'],axis = 1)
y = df['Kp']

X_train,X_test,y_train, y_test = train_test_split(X,y,test_size=0.2)

# %% [markdown]
# ## Generating model

# %%
input_shape = X_train.shape[1]

model = keras.Sequential()
model.add(layers.Input(shape=(input_shape,)))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dropout(0.1))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.2))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(32, activation='relu'))
model.add(layers.Dense(1, activation='linear'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                2368
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 128)               8320
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dense_3 (Dense)             (None, 32)                2080
#
#  dense_4 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 21057 (82.25 KB)
# Trainable params: 21057 (82.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer='adam', 
              loss='mean_squared_error',
              metrics=['mean_absolute_error'])  # You can add other metrics as needed

# %%
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.3)
# Out:
# Epoch 1/50
# 301/301 [==============================] - 1s 2ms/step - loss: 381.8418 - mean_absolute_error: 10.2388 - val_loss: 5.8616 - val_mean_absolute_error: 1.8028
# Epoch 2/50
# 301/301 [==============================] - 0s 1ms/step - loss: 11.7474 - mean_absolute_error: 2.5078 - val_loss: 1.3811 - val_mean_absolute_error: 0.8925
# Epoch 3/50
# 301/301 [==============================] - 0s 1ms/step - loss: 3.7196 - mean_absolute_error: 1.4250 - val_loss: 1.4820 - val_mean_absolute_error: 1.0185
# Epoch 4/50
# 301/301 [==============================] - 0s 1ms/step - loss: 2.2062 - mean_absolute_error: 1.1391 - val_loss: 1.3812 - val_mean_absolute_error: 0.8985
# Epoch 5/50
# 301/301 [==============================] - 0s 1ms/step - loss: 1.8548 - mean_absolute_error: 1.0456 - val_loss: 1.2782 - val_mean_absolute_error: 0.9140
# Epoch 6/50
# 301/301 [==============================] - 0s 1ms/step - loss: 1.7887 - mean_absolute_error: 1.0346 - val_loss: 1.3616 - val_mean_absolute_error: 0.8904
# Epoch 7/50
# 301/301 [==============================] - 0s 1ms/step - loss: 1.6017 - mean_absolute_error: 0.9850 - val_loss: 1.6084 - val_mean_absolute_error: 0.9394
# Epoch 8/50
# 301/301 [==============================] - 0s 1ms/step - loss: 1.5973 - mean_absolute_error: 0.9910 - val_loss: 3.3020 - val_mean_absolute_error: 1.4200
# Epoch 9/50
# 301/301 [==============================] - 0s 1ms/step - loss: 1.5813 - mean_absolute_error: 0.9820 - val_loss: 1.6676 - val_mean_absolute_error: 0.9486
# Epoch 10/50
# 301/301 [==============================] - 0s 1ms/step - loss: 1.5344 - mean_absolute_error: 0.9714 - val_loss: 1.3365 - val_mean_absolute_error: 0.8735
# Epoch 11/50
# 301/301 [==============================] - 0s 1ms/step - loss: 1.4774 - mean_absolute_error: 0.9530 - val_loss: 1.2027 - val_mean_absolute_error: 0.8850
# Epoch 12/50
# 301/301 [==============================] - 0s 1ms/step - loss: 1.4537 - mean_absolute_error: 0.9430 - val_loss: 1.5128 - val_mean_absolute_error: 0.9083
# Epoch 13/50
# 301/301 [==============================] - 0s 1ms/step - loss: 1.4191 - mean_absolute_error: 0.9347 - val_loss: 1.3589 - val_mean_absolute_error: 0.8627
# Epoch 14/50
# 301/301 [==============================] - 0s 1ms/step - loss: 1.4014 - mean_absolute_error: 0.9271 - val_loss: 1.6829 - val_mean_absolute_error: 0.9549
# Epoch 15/50
# 301/301 [==============================] - 0s 1ms/step - loss: 1.3351 - mean_absolute_error: 0.9038 - val_loss: 1.1073 - val_mean_absolute_error: 0.8103
# Epoch 16/50
# 301/301 [==============================] - 0s 1ms/step - loss: 1.3739 - mean_absolute_error: 0.9122 - val_loss: 1.1880 - val_mean_absolute_error: 0.8223
# Epoch 17/50
# 301/301 [==============================] - 0s 1ms/step - loss: 1.3689 - mean_absolute_error: 0.9151 - val_loss: 1.4505 - val_mean_absolute_error: 0.8889
# Epoch 18/50
# 301/301 [==============================] - 0s 1ms/step - loss: 1.2584 - mean_absolute_error: 0.8770 - val_loss: 1.0583 - val_mean_absolute_error: 0.8006
# Epoch 19/50
# 301/301 [==============================] - 0s 1ms/step - loss: 1.2703 - mean_absolute_error: 0.8802 - val_loss: 1.5058 - val_mean_absolute_error: 0.9087
# Epoch 20/50
# 301/301 [==============================] - 0s 1ms/step - loss: 1.2375 - mean_absolute_error: 0.8695 - val_loss: 1.4604 - val_mean_absolute_error: 0.8937
# Epoch 21/50
# 301/301 [==============================] - 0s 1ms/step - loss: 1.1868 - mean_absolute_error: 0.8569 - val_loss: 1.0161 - val_mean_absolute_error: 0.7674
# Epoch 22/50
# 301/301 [==============================] - 0s 1ms/step - loss: 1.1645 - mean_absolute_error: 0.8462 - val_loss: 1.0227 - val_mean_absolute_error: 0.7617
# Epoch 23/50
# 301/301 [==============================] - 0s 1ms/step - loss: 1.1323 - mean_absolute_error: 0.8329 - val_loss: 1.1506 - val_mean_absolute_error: 0.8004
# Epoch 24/50
# 301/301 [==============================] - 0s 1ms/step - loss: 1.1067 - mean_absolute_error: 0.8212 - val_loss: 0.9306 - val_mean_absolute_error: 0.7334
# Epoch 25/50
# 301/301 [==============================] - 0s 1ms/step - loss: 1.1012 - mean_absolute_error: 0.8170 - val_loss: 1.0655 - val_mean_absolute_error: 0.7769
# Epoch 26/50
# 301/301 [==============================] - 0s 1ms/step - loss: 1.0342 - mean_absolute_error: 0.7925 - val_loss: 1.0700 - val_mean_absolute_error: 0.7753
# Epoch 27/50
# 301/301 [==============================] - 0s 1ms/step - loss: 1.0332 - mean_absolute_error: 0.7909 - val_loss: 0.9153 - val_mean_absolute_error: 0.7304
# Epoch 28/50
# 301/301 [==============================] - 0s 1ms/step - loss: 1.0034 - mean_absolute_error: 0.7819 - val_loss: 1.2099 - val_mean_absolute_error: 0.8192
# Epoch 29/50
# 301/301 [==============================] - 0s 1ms/step - loss: 1.0199 - mean_absolute_error: 0.7836 - val_loss: 1.1585 - val_mean_absolute_error: 0.8016
# Epoch 30/50
# 301/301 [==============================] - 0s 1ms/step - loss: 0.9756 - mean_absolute_error: 0.7660 - val_loss: 1.2768 - val_mean_absolute_error: 0.8355
# Epoch 31/50
# 301/301 [==============================] - 0s 1ms/step - loss: 1.0021 - mean_absolute_error: 0.7760 - val_loss: 0.9477 - val_mean_absolute_error: 0.7348
# Epoch 32/50
# 301/301 [==============================] - 0s 1ms/step - loss: 0.9447 - mean_absolute_error: 0.7544 - val_loss: 1.2862 - val_mean_absolute_error: 0.8362
# Epoch 33/50
# 301/301 [==============================] - 0s 1ms/step - loss: 0.9350 - mean_absolute_error: 0.7514 - val_loss: 1.2135 - val_mean_absolute_error: 0.8174
# Epoch 34/50
# 301/301 [==============================] - 0s 1ms/step - loss: 0.9307 - mean_absolute_error: 0.7448 - val_loss: 1.1349 - val_mean_absolute_error: 0.7953
# Epoch 35/50
# 301/301 [==============================] - 0s 1ms/step - loss: 0.9053 - mean_absolute_error: 0.7409 - val_loss: 0.9357 - val_mean_absolute_error: 0.7348
# Epoch 36/50
# 301/301 [==============================] - 0s 1ms/step - loss: 0.9194 - mean_absolute_error: 0.7417 - val_loss: 0.9522 - val_mean_absolute_error: 0.7412
# Epoch 37/50
# 301/301 [==============================] - 0s 1ms/step - loss: 0.9011 - mean_absolute_error: 0.7372 - val_loss: 0.8638 - val_mean_absolute_error: 0.7074
# Epoch 38/50
# 301/301 [==============================] - 0s 1ms/step - loss: 0.8909 - mean_absolute_error: 0.7337 - val_loss: 0.9183 - val_mean_absolute_error: 0.7258
# Epoch 39/50
# 301/301 [==============================] - 0s 1ms/step - loss: 0.8809 - mean_absolute_error: 0.7262 - val_loss: 0.9451 - val_mean_absolute_error: 0.7353
# Epoch 40/50
# 301/301 [==============================] - 0s 1ms/step - loss: 0.8546 - mean_absolute_error: 0.7143 - val_loss: 0.9101 - val_mean_absolute_error: 0.7183
# Epoch 41/50
# 301/301 [==============================] - 0s 1ms/step - loss: 0.8684 - mean_absolute_error: 0.7213 - val_loss: 0.8425 - val_mean_absolute_error: 0.6935
# Epoch 42/50
# 301/301 [==============================] - 0s 1ms/step - loss: 0.8533 - mean_absolute_error: 0.7156 - val_loss: 0.7926 - val_mean_absolute_error: 0.6924
# Epoch 43/50
# 301/301 [==============================] - 0s 1ms/step - loss: 0.8511 - mean_absolute_error: 0.7144 - val_loss: 0.8607 - val_mean_absolute_error: 0.7024
# Epoch 44/50
# 301/301 [==============================] - 0s 1ms/step - loss: 0.8252 - mean_absolute_error: 0.7037 - val_loss: 0.7815 - val_mean_absolute_error: 0.6878
# Epoch 45/50
# 301/301 [==============================] - 0s 1ms/step - loss: 0.8323 - mean_absolute_error: 0.7076 - val_loss: 0.8162 - val_mean_absolute_error: 0.6905
# Epoch 46/50
# 301/301 [==============================] - 0s 1ms/step - loss: 0.8467 - mean_absolute_error: 0.7093 - val_loss: 0.7746 - val_mean_absolute_error: 0.6782
# Epoch 47/50
# 301/301 [==============================] - 0s 1ms/step - loss: 0.9104 - mean_absolute_error: 0.7323 - val_loss: 0.8595 - val_mean_absolute_error: 0.7142
# Epoch 48/50
# 301/301 [==============================] - 0s 1ms/step - loss: 0.8435 - mean_absolute_error: 0.7132 - val_loss: 0.8357 - val_mean_absolute_error: 0.6928
# Epoch 49/50
# 301/301 [==============================] - 0s 1ms/step - loss: 0.8402 - mean_absolute_error: 0.7104 - val_loss: 0.9418 - val_mean_absolute_error: 0.7277
# Epoch 50/50
# 301/301 [==============================] - 0s 1ms/step - loss: 0.8460 - mean_absolute_error: 0.7105 - val_loss: 0.8267 - val_mean_absolute_error: 0.6968

# %%
fig, axs = plt.subplots(1, 2, figsize=(8, 4))  # 2 rows, 1 column

# Plot the first subplot (Training Loss and Validation Loss)
axs[0].plot(history.history['loss'], label='Training Loss')
axs[0].plot(history.history['val_loss'], label='Validation Loss')
axs[0].set_title('Model Loss')
axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Loss')
axs[0].legend()
axs[0].grid(True)

# Plot the second subplot (Training MAE and Validation MAE)
axs[1].plot(history.history['mean_absolute_error'], label='Training MAE')
axs[1].plot(history.history['val_mean_absolute_error'], label='Validation MAE')
axs[1].set_title('Mean Absolute Error (MAE)')
axs[1].set_xlabel('Epoch')
axs[1].set_ylabel('MAE')
axs[1].legend()
axs[1].grid(True)

plt.tight_layout()
plt.show()

# %%
y_pred = model.predict(X_test)

# Calculate MAE
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)

print(f'Mean Absolute Error (MAE): {mae:.2f}')
print(f'Mean Squared Error (MSE): {mse:.2f}')
# Out:
# 108/108 [==============================] - 0s 602us/step
# Mean Absolute Error (MAE): 0.69
# Mean Squared Error (MSE): 0.84

# %%
y_pred
# Out:
# array([[2.436776 ],
#        [2.5473425],
#        [1.2890673],
#        ...,
#        [2.5674133],
#        [1.7584121],
#        [2.3619192]], dtype=float32)

# %%
plt.figure(figsize=(12,8))
plt.plot(np.arange(len(y_test)), y_test, label='y_test', marker='o')
plt.plot(np.arange(len(y_test)), y_pred, label='y_pred', marker='x', c='r')
plt.show()
