# %%
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow
import keras
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
df = pd.read_pickle('./data/final_df')

# %%
X = df.drop(['Kp','ap'],axis = 1)
y = df['Kp']

X_train,X_test,y_train, y_test = train_test_split(X,y,test_size=0.2)

# %% [markdown]
# ## Generating model

# %%
input_shape = X_train.shape[1]

model = keras.Sequential()
model.add(layers.Input(shape=(input_shape,)))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dropout(0.1))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.2))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(32, activation='relu'))
model.add(layers.Dense(1, activation='linear'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                2368
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 128)               8320
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dense_3 (Dense)             (None, 32)                2080
#
#  dense_4 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 21057 (82.25 KB)
# Trainable params: 21057 (82.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer='adam', 
              loss='mean_squared_error',
              metrics=['mean_absolute_error'])  # You can add other metrics as needed

# %%
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.3)
# Out:
# Epoch 1/50
# 301/301 [==============================] - 1s 2ms/step - loss: 193.5455 - mean_absolute_error: 7.2925 - val_loss: 3.0574 - val_mean_absolute_error: 1.2936
# Epoch 2/50
# 301/301 [==============================] - 0s 1ms/step - loss: 10.4113 - mean_absolute_error: 2.3802 - val_loss: 2.1993 - val_mean_absolute_error: 1.0754
# Epoch 3/50
# 301/301 [==============================] - 0s 1ms/step - loss: 4.2232 - mean_absolute_error: 1.5319 - val_loss: 2.0680 - val_mean_absolute_error: 1.0625
# Epoch 4/50
# 301/301 [==============================] - 1s 2ms/step - loss: 2.8302 - mean_absolute_error: 1.2752 - val_loss: 2.2538 - val_mean_absolute_error: 1.1280
# Epoch 5/50
# 301/301 [==============================] - 1s 3ms/step - loss: 2.1690 - mean_absolute_error: 1.1333 - val_loss: 1.4583 - val_mean_absolute_error: 0.9198
# Epoch 6/50
# 301/301 [==============================] - 1s 5ms/step - loss: 1.8973 - mean_absolute_error: 1.0563 - val_loss: 1.3097 - val_mean_absolute_error: 0.8564
# Epoch 7/50
# 301/301 [==============================] - 1s 2ms/step - loss: 1.6451 - mean_absolute_error: 0.9989 - val_loss: 1.4226 - val_mean_absolute_error: 0.8942
# Epoch 8/50
# 301/301 [==============================] - 1s 2ms/step - loss: 1.5227 - mean_absolute_error: 0.9615 - val_loss: 1.1867 - val_mean_absolute_error: 0.8338
# Epoch 9/50
# 301/301 [==============================] - 1s 2ms/step - loss: 1.4347 - mean_absolute_error: 0.9357 - val_loss: 1.2137 - val_mean_absolute_error: 0.8372
# Epoch 10/50
# 301/301 [==============================] - 1s 2ms/step - loss: 1.4319 - mean_absolute_error: 0.9346 - val_loss: 1.5361 - val_mean_absolute_error: 0.9035
# Epoch 11/50
# 301/301 [==============================] - 1s 2ms/step - loss: 1.3578 - mean_absolute_error: 0.9134 - val_loss: 1.2422 - val_mean_absolute_error: 0.8370
# Epoch 12/50
# 301/301 [==============================] - 1s 3ms/step - loss: 1.3279 - mean_absolute_error: 0.8982 - val_loss: 1.0890 - val_mean_absolute_error: 0.8119
# Epoch 13/50
# 301/301 [==============================] - 1s 5ms/step - loss: 1.3018 - mean_absolute_error: 0.8880 - val_loss: 1.1104 - val_mean_absolute_error: 0.7975
# Epoch 14/50
# 301/301 [==============================] - 1s 4ms/step - loss: 1.2692 - mean_absolute_error: 0.8822 - val_loss: 1.3753 - val_mean_absolute_error: 0.8601
# Epoch 15/50
# 301/301 [==============================] - 1s 4ms/step - loss: 1.2535 - mean_absolute_error: 0.8761 - val_loss: 1.2087 - val_mean_absolute_error: 0.8130
# Epoch 16/50
# 301/301 [==============================] - 1s 5ms/step - loss: 1.2619 - mean_absolute_error: 0.8747 - val_loss: 1.0518 - val_mean_absolute_error: 0.7831
# Epoch 17/50
# 301/301 [==============================] - 2s 6ms/step - loss: 1.2057 - mean_absolute_error: 0.8551 - val_loss: 1.0039 - val_mean_absolute_error: 0.7734
# Epoch 18/50
# 301/301 [==============================] - 2s 5ms/step - loss: 1.2013 - mean_absolute_error: 0.8558 - val_loss: 1.0659 - val_mean_absolute_error: 0.7779
# Epoch 19/50
# 301/301 [==============================] - 1s 3ms/step - loss: 1.1948 - mean_absolute_error: 0.8492 - val_loss: 1.0032 - val_mean_absolute_error: 0.7651
# Epoch 20/50
# 301/301 [==============================] - 1s 3ms/step - loss: 1.1522 - mean_absolute_error: 0.8317 - val_loss: 1.2868 - val_mean_absolute_error: 0.8323
# Epoch 21/50
# 301/301 [==============================] - 1s 2ms/step - loss: 1.1696 - mean_absolute_error: 0.8399 - val_loss: 1.0409 - val_mean_absolute_error: 0.7559
# Epoch 22/50
# 301/301 [==============================] - 1s 2ms/step - loss: 1.1658 - mean_absolute_error: 0.8298 - val_loss: 0.9126 - val_mean_absolute_error: 0.7405
# Epoch 23/50
# 301/301 [==============================] - 1s 4ms/step - loss: 1.1002 - mean_absolute_error: 0.8098 - val_loss: 0.9346 - val_mean_absolute_error: 0.7320
# Epoch 24/50
# 301/301 [==============================] - 1s 3ms/step - loss: 1.0957 - mean_absolute_error: 0.8068 - val_loss: 1.2164 - val_mean_absolute_error: 0.8108
# Epoch 25/50
# 301/301 [==============================] - 2s 5ms/step - loss: 1.0719 - mean_absolute_error: 0.7996 - val_loss: 0.9271 - val_mean_absolute_error: 0.7305
# Epoch 26/50
# 301/301 [==============================] - 1s 4ms/step - loss: 1.0187 - mean_absolute_error: 0.7793 - val_loss: 0.8732 - val_mean_absolute_error: 0.7133
# Epoch 27/50
# 301/301 [==============================] - 1s 2ms/step - loss: 1.0269 - mean_absolute_error: 0.7844 - val_loss: 0.8758 - val_mean_absolute_error: 0.7143
# Epoch 28/50
# 301/301 [==============================] - 1s 2ms/step - loss: 1.0188 - mean_absolute_error: 0.7742 - val_loss: 0.9083 - val_mean_absolute_error: 0.7181
# Epoch 29/50
# 301/301 [==============================] - 1s 2ms/step - loss: 1.0276 - mean_absolute_error: 0.7762 - val_loss: 1.2050 - val_mean_absolute_error: 0.8106
# Epoch 30/50
# 301/301 [==============================] - 1s 2ms/step - loss: 0.9767 - mean_absolute_error: 0.7611 - val_loss: 0.9411 - val_mean_absolute_error: 0.7226
# Epoch 31/50
# 301/301 [==============================] - 1s 2ms/step - loss: 0.9515 - mean_absolute_error: 0.7544 - val_loss: 0.7882 - val_mean_absolute_error: 0.6955
# Epoch 32/50
# 301/301 [==============================] - 1s 2ms/step - loss: 0.9728 - mean_absolute_error: 0.7607 - val_loss: 0.8816 - val_mean_absolute_error: 0.7058
# Epoch 33/50
# 301/301 [==============================] - 0s 2ms/step - loss: 0.9324 - mean_absolute_error: 0.7440 - val_loss: 0.9217 - val_mean_absolute_error: 0.7392
# Epoch 34/50
# 301/301 [==============================] - 0s 1ms/step - loss: 0.9653 - mean_absolute_error: 0.7556 - val_loss: 0.9751 - val_mean_absolute_error: 0.7363
# Epoch 35/50
# 301/301 [==============================] - 0s 1ms/step - loss: 0.9558 - mean_absolute_error: 0.7526 - val_loss: 0.9028 - val_mean_absolute_error: 0.7133
# Epoch 36/50
# 301/301 [==============================] - 0s 1ms/step - loss: 0.9045 - mean_absolute_error: 0.7326 - val_loss: 0.8947 - val_mean_absolute_error: 0.7068
# Epoch 37/50
# 301/301 [==============================] - 0s 1ms/step - loss: 0.8980 - mean_absolute_error: 0.7332 - val_loss: 1.0441 - val_mean_absolute_error: 0.7626
# Epoch 38/50
# 301/301 [==============================] - 0s 1ms/step - loss: 0.9036 - mean_absolute_error: 0.7301 - val_loss: 0.8244 - val_mean_absolute_error: 0.6924
# Epoch 39/50
# 301/301 [==============================] - 0s 1ms/step - loss: 0.9423 - mean_absolute_error: 0.7451 - val_loss: 0.9311 - val_mean_absolute_error: 0.7257
# Epoch 40/50
# 301/301 [==============================] - 0s 2ms/step - loss: 0.9439 - mean_absolute_error: 0.7424 - val_loss: 0.7871 - val_mean_absolute_error: 0.6884
# Epoch 41/50
# 301/301 [==============================] - 1s 2ms/step - loss: 0.8928 - mean_absolute_error: 0.7288 - val_loss: 0.8142 - val_mean_absolute_error: 0.6882
# Epoch 42/50
# 301/301 [==============================] - 1s 2ms/step - loss: 0.9106 - mean_absolute_error: 0.7343 - val_loss: 0.8753 - val_mean_absolute_error: 0.7063
# Epoch 43/50
# 301/301 [==============================] - 1s 4ms/step - loss: 0.9135 - mean_absolute_error: 0.7329 - val_loss: 0.7453 - val_mean_absolute_error: 0.6704
# Epoch 44/50
# 301/301 [==============================] - 1s 4ms/step - loss: 0.8867 - mean_absolute_error: 0.7231 - val_loss: 0.7810 - val_mean_absolute_error: 0.6782
# Epoch 45/50
# 301/301 [==============================] - 1s 3ms/step - loss: 0.8831 - mean_absolute_error: 0.7194 - val_loss: 0.7214 - val_mean_absolute_error: 0.6808
# Epoch 46/50
# 301/301 [==============================] - 1s 3ms/step - loss: 0.8640 - mean_absolute_error: 0.7193 - val_loss: 0.7474 - val_mean_absolute_error: 0.6707
# Epoch 47/50
# 301/301 [==============================] - 1s 3ms/step - loss: 0.8984 - mean_absolute_error: 0.7212 - val_loss: 0.8373 - val_mean_absolute_error: 0.6939
# Epoch 48/50
# 301/301 [==============================] - 1s 3ms/step - loss: 0.8426 - mean_absolute_error: 0.7069 - val_loss: 0.7620 - val_mean_absolute_error: 0.6662
# Epoch 49/50
# 301/301 [==============================] - 1s 3ms/step - loss: 0.8267 - mean_absolute_error: 0.7033 - val_loss: 0.8627 - val_mean_absolute_error: 0.7077
# Epoch 50/50
# 301/301 [==============================] - 1s 2ms/step - loss: 0.8588 - mean_absolute_error: 0.7145 - val_loss: 0.7733 - val_mean_absolute_error: 0.6805

# %%
fig, axs = plt.subplots(1, 2, figsize=(8, 4))  # 2 rows, 1 column

# Plot the first subplot (Training Loss and Validation Loss)
axs[0].plot(history.history['loss'], label='Training Loss')
axs[0].plot(history.history['val_loss'], label='Validation Loss')
axs[0].set_title('Model Loss')
axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Loss')
axs[0].legend()
axs[0].grid(True)

# Plot the second subplot (Training MAE and Validation MAE)
axs[1].plot(history.history['mean_absolute_error'], label='Training MAE')
axs[1].plot(history.history['val_mean_absolute_error'], label='Validation MAE')
axs[1].set_title('Mean Absolute Error (MAE)')
axs[1].set_xlabel('Epoch')
axs[1].set_ylabel('MAE')
axs[1].legend()
axs[1].grid(True)

plt.tight_layout()
plt.show()

# %%
y_pred = model.predict(X_test)

# Calculate MAE
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)

print(f'Mean Absolute Error (MAE): {mae:.2f}')
print(f'Mean Squared Error (MSE): {mse:.2f}')
# Out:
# 108/108 [==============================] - 0s 731us/step
# Mean Absolute Error (MAE): 0.70
# Mean Squared Error (MSE): 0.81

# %%
y_pred
# Out:
# array([[2.119488  ],
#        [2.0665455 ],
#        [1.0852981 ],
#        ...,
#        [4.2682037 ],
#        [0.96101636],
#        [0.67820925]], dtype=float32)

# %%
plt.figure(figsize=(12,8))
plt.plot(np.arange(len(y_test)), y_test, label='y_test', marker='o')
plt.plot(np.arange(len(y_test)), y_pred, label='y_pred', marker='x', c='r')
plt.show()

# %%
model.save('./chekpoint_models/realtime')
# Out:
# INFO:tensorflow:Assets written to: ./chekpoint_models/realtime\assets
# INFO:tensorflow:Assets written to: ./chekpoint_models/realtime\assets
